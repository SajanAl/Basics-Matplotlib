# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5,6]
y=[50,45,55,35,60,25]
#plt.plot(x,y,'rD--')
# plt.plot(x,y,color='red',marker="D",linestyle='--',markersize=15,alpha=0.89)

# %%
plt.plot(x,y,linestyle='dashdot')

# %%
plt.plot(x,y,linestyle='dotted')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='dashdot')

# %%
#axis label,legend,grid
days=[1,2,3,4,5,6]
max_t=[50,45,55,35,60,25]
min_t=[40,35,38,32,33,30]
avg_t=[45,44,46,43,43,42]
plt.xlabel('Days')
plt.ylabel("Temprature")
plt.plot(days,max_t,label="Max")
plt.plot(days,min_t,label="Min")
plt.plot(days,avg_t,label="Avg")
plt.legend(loc='best',shadow=True,fontsize='large')

# %% [markdown]
# # Bar Chart

# %%
company=['Google','Facebook','Twitter','Youtube']
revenue=[100,90,130,85]
profit=[20,70,40,50]
ypos=np.arange(len(company))
ypos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xlabel('Company')
plt.ylabel('Revenue')
plt.title('Badjet')
plt.xticks(ypos,company)                   #convert integer into string
plt.bar(ypos,revenue,color='red',label='Revenue')
plt.bar(ypos,profit,label="Profit")
plt.legend(loc='best',fontsize='large',shadow=True)

# %%
company=['Google','Facebook','Twitter','Youtube']
revenue=[100,90,130,85]
profit=[20,70,40,50]
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xlabel('Company')
plt.ylabel("Revenue")
plt.xticks(xpos,company)
plt.bar(xpos-0.2,revenue,label="Revenue",color='red',width=0.4)
plt.bar(xpos+0.2,profit,label="Profit",color='yellow',width=0.4)
plt.grid()
plt.legend()

# %%
blood_sugar_men=[95,80,120,125,100,134,150,110,105,90]
blood_sugar_woman=[100,90,80,110,115,105,120,130,130,150]
plt.xlabel("Sugar range")
plt.ylabel('Total number of patient')
plt.title("Blood Sugar Analysis")
plt.hist([blood_sugar_men,blood_sugar_woman],bins=[80,100,125,150],rwidth=0.95,color=['red','green'],label=['Men','Women'])
plt.legend(shadow=True)
plt.savefig("BloodAnalysis.png")

# %% [markdown]
# # Pie chart

# %%
exp_vals=[1000,900,500,700,800]
exp_labels=['Home Rent','Food','Car','Phone','Laptop']

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=1,autopct='%0.2f%%',explode=[0.1,0,0.1,0,0],shadow=True,startangle=90)
plt.savefig("piechart.png")

# %% [markdown]
# # Polar plot

# %%
r = np.arange(0, 5, 0.01)
theta = 2 * np.pi * r

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %% [markdown]
# # Scatter plot on polar axis

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
N = 200
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.8)

# %% [markdown]
# # Scatter plot on polar axis, with offset origin

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

ax.set_rorigin(-2.5)
ax.set_theta_zero_location('W', offset=10)

# %% [markdown]
# # Scatter plot on polar axis confined to a sector

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

ax.set_thetamin(45)
ax.set_thetamax(135)

plt.show()

# %% [markdown]
# # Simple Plot

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s,)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets')
ax.grid()

# fig.savefig("test.png")
plt.show()
